# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfessorPatrickSlatraigh/CIS2300/blob/main/CIS2300_BTRA_Spr2025_Chapter_03_11_Feb_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <b>CST2300: Chapter 03 - <u>Debugging Interlude</u></b>
#
# <i>by Professor Patrick, Feb-2025</i>
#
# <i><font color='green'>note: there is a [student version of this Colab notebook available online](https://bit.ly/cis2300chapter3)<font color='green'> at bit.ly/cis2300chapter3</i></font>

# %% [markdown]
# **Examples** from:
# # Chapter 3 (Debugging Interlude)
# *as offered on Runestone.academy*
# *this chapter is not in the original Python For Everybody (py4e.com/lessons)*

# %% [markdown]
# ##3. Debugging Examples

# %% [markdown]
# Before we start, let's use the `input()` function.

# %%
print("Hello World!")

# %% [markdown]
# What if we want to ask the user what to print?

# %%
what2print = input("What do you want to print? ")
print(what2print)

# %% [markdown]
# ---

# %% [markdown]
# Some examples from Runestone...

# %% [markdown]
# ### 3.2.2

# %%
current_time = input("What is the current time (in hours 0 - 23)?")
wait_time = input("How many hours do you want to wait")

print(current_time)
print(wait_time)

final_time = current_time + wait_time
print(final_time)

# %%
type(current_time)

# %%
type(wait_time)

# %%
type(final_time)

# %% [markdown]
# Wait!  What!   How can we make an integer out of the string that was returned by `input()`?

# %% [markdown]
# We can use the `int()` function.

# %%
current_time_int = int(current_time)
wait_time_int = int(wait_time)
print(current_time_int + wait_time_int)

# %% [markdown]
# What about starting at 23:00 and waiting 3 hours?
#
# Would the `mod()` function help?

# %%
print((current_time_int+wait_time_int) % 24)

# %% [markdown]
# ###3.2.5

# %%
current_time_str = input("What is the current time (in hours 0-23)?")
wait_time_str = input("How many hours do you want to wait")

current_time_int = int(current_time_str)
wait_time_int = int(wait_time_str)

final_time_int = current_time_int + wait_time_int

final_answer = final_time_int % 24

print("The time after waiting is: ", final_answer)

# %% [markdown]
# ###3.4.1

# %%
current_time_str = input("What is the current time (in hours 0-23)?")
wait_time_str = input("How many hours do you want to wait")

current_time_int = int(current_time_str)
wait_time_int = int(wait_time_int)

final_time_int = current_time_int + wait_time_int
print(final_time_int)

# %% [markdown]
# Some of the common errors and their frequency, according to Runestone:

# %% [markdown]
# ![runestone_3-4_commonErrors.png](data:image/png;base64,...)

# %% [markdown]
# ###3.4.1 Parse Error

# %%
current_time_str = input("What is the current time (in hours 0-23)?")
wait_time_str = input("How many hours do you want to wait"

current_time_int = int(current_time_str)
wait_time_int = int(wait_time_str)

final_time_int = current_time_int + wait_time_int
print(final_time_int)

# %% [markdown]
# ###3.4.2 Type Error

# %%
a = input('wpisz godzine')
x = input('wpisz liczbe godzin')
int(x)
int(a)
h = x // 24
s = x % 24
print (h, s)
a = a + s
print ('godzina teraz', a)

# %% [markdown]
# ### 3.4.3 Name Error

# %%
str_time = input("What time is it now?")
str_wait_time = input("What is the number of nours to wait?")
time = int(str_time)
wai_time = int(str_wait_time)

time_when_alarm_go_off = time + wait_time
print(time_when_alarm_go_off)

# %% [markdown]
# ### 3.4.4 Value Error

# %%
current_time_str = input("What is the current time (in hours 0-23)?")
current_time_int = int(current_time_str)

wait_time_str = input("How many hours do you want to wait")
wait_time_int = int(wait_time_int)

final_time_int = current_time_int + wait_time_int
print(final_time_int)

# %% [markdown]
# ---

# %% [markdown]
# ## Team Exercise

# %% [markdown]
# Pair-up with another student.  Each student should write one of the following programs and then ask your partner to use the program.  What went wrong?

# %% [markdown]
# ### Exercise Program 1 - Fahrenheit to Celsius
#
# Write a program that asks the user for the temperature in Fahrenheit and tells them the temperature in Celsius.
#
# <font color='blue'><i>hint: Celsius = (Fahrenehit - 32)  * (5/9)</i></font>

# %%
# Your code here

# %% [markdown]
# ### Exercise Program 2 - Hypoteneuse from Sides
#
# Write a program that asks the user for the length of each side of a right triangle and tells them the length of the hypoteneuse.
#
# <font color='blue'><i>hint: Hypoteneuse = SQRT of ((SideA Squared) + (SideB Squared))</i></font>

# %%
# Your code here

# %% [markdown]
# ---

# %% [markdown]
# **See the class notes on Brightspace and the Runestone material on Runestone.Academy for more information.**

# %% [markdown]
# ---
